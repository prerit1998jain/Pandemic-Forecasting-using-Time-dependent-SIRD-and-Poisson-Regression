# %%
# Importing Packages

import pandas as pd
from patsy import dmatrices
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
# Reading the dataset
data_tests = pd.read_csv('Country-wise_data_testing_information/USA_data.csv')
data_policy = pd.read_excel('Cases_and_policies_Country_wise/USA_Covid_Cases_and_Policies.xlsx')

# %%
data_tests.head(100)
# Out:
#        dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0   31-12-2019   31     12  2019      0       0          United_Kingdom    UK
# 1   01-01-2020    1      1  2020      0       0          United_Kingdom    UK
# 2   02-01-2020    2      1  2020      0       0          United_Kingdom    UK
# 3   03-01-2020    3      1  2020      0       0          United_Kingdom    UK
# 4   04-01-2020    4      1  2020      0       0          United_Kingdom    UK
# 5   05-01-2020    5      1  2020      0       0          United_Kingdom    UK
# 6   06-01-2020    6      1  2020      0       0          United_Kingdom    UK
# 7   07-01-2020    7      1  2020      0       0          United_Kingdom    UK
# 8   08-01-2020    8      1  2020      0       0          United_Kingdom    UK
# 9   09-01-2020    9      1  2020      0       0          United_Kingdom    UK
# 10  10-01-2020   10      1  2020      0       0          United_Kingdom    UK
# ...

# %%
data_policy.head()
# Out:
#    Unnamed: 0        day Country              Country Name Region  Deaths  \
# 0           0 2020-01-21      US  United States of America   AMRO       0
# 1           1 2020-01-22      US  United States of America   AMRO       0
# 2           2 2020-01-23      US  United States of America   AMRO       0
# 3           3 2020-01-24      US  United States of America   AMRO       0
# 4           4 2020-01-25      US  United States of America   AMRO       0
#
#    Cumulative Deaths  Confirmed  Cumulative Confirmed  Lockdown  ...  \
# 0                  0          1                     1         0  ...
# 1                  0          0                     1         0  ...
# 2                  0          0                     1         0  ...
# 3                  0          0                     1         0  ...
# 4                  0          1                     2         0  ...
#
#    Governance and socio-economic measures  Humanitarian exemption  \
# ...
